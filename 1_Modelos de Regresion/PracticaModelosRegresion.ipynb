# %%
#Cossio Vidaurre José Alejandro

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Dummy_Data_HSS.csv')
dataset.head(10)
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181
# 5  29.0   9.614382      1.027163       Mega  105.889148
# 6  55.0  24.893811      4.273602      Micro  198.679825
# 7  31.0  17.355042      2.289855       Nano  108.733932
# 8  76.0  24.648898      7.130116      Macro  270.189400
# 9  13.0   0.431128      2.229423       Mega   48.280582

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV            4562 non-null   float64
#  1   Radio         4568 non-null   float64
#  2   Social Media  4566 non-null   float64
#  3   Influencer    4572 non-null   object
#  4   Sales         4566 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 178.7+ KB

# %%
#Contando los datos nulos
dataset.isnull().sum(axis = 0)
# Out:
# TV              10
# Radio            4
# Social Media     6
# Influencer       0
# Sales            6
# dtype: int64

# %%
#Al ver que hay datos nulos y no son muchos, una opcion es eliminarlos
dataset.dropna(inplace = True)

# %%
#Comprobando los datos nulos
dataset.isnull().sum(axis = 0)
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %%
#Elejimos los valores para cada variable
X = dataset.iloc[:, 0].values #Se elige la columna de TV
y = dataset.iloc[:, -1].values #Se elige la columna de Sales
#La razon, es debido a que existe una linea de codigo
#dataset.corr() que muestra la correlacion de las columnas
#De las cuales, las columnas elegidas son las que tienen mayor correlacion entre ambas

# %%
X
# Out:
# array([16., 13., 41., ..., 44., 71., 42.])

# %%
y
# Out:
# array([ 54.73275715,  46.67789698, 150.1778288 , ..., 163.6314574 ,
#        253.6104113 , 148.2024141 ])

# %%
#Al momento de querer realizar el entrenamiento, daba un error que se solucionaba con un reshape
#Debido a eso, las variables "X" y "y" se los convirtio a numpy.array para hacer correctamente el reshape
#Pudiendo asi, realizar el entrenamiento con este modelo

# %%
X = np.array(X)
X
# Out:
# array([16., 13., 41., ..., 44., 71., 42.])

# %%
X = X.reshape(-1,1)
X
# Out:
# array([[16.],
#        [13.],
#        [41.],
#        ...,
#        [44.],
#        [71.],
#        [42.]])

# %%
y = np.array(y)
y
# Out:
# array([ 54.73275715,  46.67789698, 150.1778288 , ..., 163.6314574 ,
#        253.6104113 , 148.2024141 ])

# %%
y = y.reshape(-1,1)
y
# Out:
# array([[ 54.73275715],
#        [ 46.67789698],
#        [150.1778288 ],
#        ...,
#        [163.6314574 ],
#        [253.6104113 ],
#        [148.2024141 ]])

# %%
#Segmentacion de las variables
from sklearn.model_selection import train_test_split
X_train_Simple, X_test_Simple, y_train_Simple, y_test_Simple = train_test_split(X,y,test_size=0.2, random_state= 1)

# %%
#REGRESION LINEAL SIMPLE
#========================
# Entrenamiento
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_Simple, y_train_Simple)
# Out:
# LinearRegression()

# %%
#Prediccion
y_pred = regressor.predict(X_test_Simple)
y_pred #respuestas del estudiante
# Out:
# array([[331.12749332],
#        [ 96.01868115],
#        [352.5010217 ],
#        [213.57308724],
#        [124.51671899],
#        [356.06327643],
#        [ 60.39613385],
#        [302.62945548],
#        [ 81.76966223],
#        [284.81818183],
#        [202.88632305],
#        [124.51671899],
#        [145.89024737],
#        [ 60.39613385],
#        [242.07112508],
#        [138.76573791],
#        [295.50494602],
#        [245.63337981],
#        [277.69367237],
#        [ 99.58093588],
#        [113.8299548 ],
#        [316.8784744 ],
#        [ 35.46035074],
#        [327.56523859],
#        [327.56523859],
#        [170.82603048],
#        [309.75396494],
#        [252.75788926],
#        [110.26770007],
#        [284.81818183],
#        [220.6975967 ],
#        [334.68974805],
#        [295.50494602],
#        [245.63337981],
#        [ 71.08289804],
#        [149.4525021 ],
#        [ 85.33191696],
#        [338.25200278],
#        [341.81425751],
#        [156.57701156],
# ...

# %%
print(X_test_Simple)
# Out:
# [[ 93.]
#  [ 27.]
#  [ 99.]
#  [ 60.]
#  [ 35.]
#  [100.]
#  [ 17.]
#  [ 85.]
#  [ 23.]
#  [ 80.]
#  [ 57.]
#  [ 35.]
#  [ 41.]
#  [ 17.]
#  [ 68.]
#  [ 39.]
#  [ 83.]
#  [ 69.]
#  [ 78.]
#  [ 28.]
#  [ 32.]
#  [ 89.]
#  [ 10.]
#  [ 92.]
#  [ 92.]
#  [ 48.]
#  [ 87.]
#  [ 71.]
#  [ 31.]
#  [ 80.]
#  [ 62.]
#  [ 94.]
#  [ 83.]
#  [ 69.]
#  [ 20.]
#  [ 42.]
#  [ 24.]
#  [ 95.]
#  [ 96.]
#  [ 44.]
#  [ 47.]
#  [ 70.]
#  [ 47.]
#  [ 37.]
#  [ 45.]
#  [ 17.]
#  [ 14.]
#  [ 98.]
#  [ 25.]
#  [ 87.]
#  [ 54.]
#  [ 86.]
#  [ 43.]
#  [ 66.]
#  [ 93.]
#  [ 59.]
#  [ 46.]
#  [ 30.]
#  [ 97.]
#  [ 30.]
#  [ 57.]
#  [ 81.]
#  [ 92.]
#  [ 44.]
#  [ 45.]
#  [ 76.]
#  [ 85.]
#  [ 77.]
#  [ 68.]
#  [ 68.]
#  [ 28.]
#  [ 46.]
#  [ 40.]
#  [ 81.]
#  [ 82.]
#  [ 19.]
#  [ 37.]
#  [ 59.]
#  [100.]
#  [ 51.]
#  [ 90.]
#  [ 32.]
#  [ 84.]
#  [ 35.]
#  [ 87.]
#  [ 54.]
#  [ 60.]
#  [ 95.]
#  [ 96.]
#  [ 90.]
#  [ 18.]
#  [ 85.]
#  [ 30.]
#  [ 50.]
#  [ 76.]
#  [ 39.]
#  [ 16.]
#  [ 74.]
#  [ 71.]
#  [ 38.]
# ...

# %%
print(y_test_Simple) #datos del examen como ejemplo
# Out:
# [[329.1478082 ]
#  [100.1458568 ]
#  [352.6886614 ]
#  [213.482651  ]
#  [128.4717346 ]
#  [352.0133529 ]
#  [ 60.70006263]
#  [300.0219219 ]
#  [ 80.70133466]
#  [286.0300404 ]
#  [201.4312428 ]
#  [121.8138666 ]
#  [146.0486457 ]
#  [ 58.92532301]
#  [244.6335186 ]
#  [138.4315947 ]
#  [301.0213397 ]
#  [246.9671859 ]
#  [271.1260094 ]
#  [ 97.2436394 ]
#  [115.6143077 ]
#  [315.4790544 ]
#  [ 34.20517016]
#  [328.2393781 ]
#  [327.5925024 ]
#  [174.4335283 ]
#  [307.9893433 ]
#  [255.9716288 ]
#  [112.9525763 ]
#  [285.2438359 ]
#  [222.8035563 ]
#  [334.7867143 ]
#  [294.4679527 ]
#  [244.3754776 ]
#  [ 72.99721493]
#  [145.2658074 ]
#  [ 86.22925533]
#  [333.9225156 ]
#  [343.006536  ]
#  [153.5822256 ]
#  [164.2736798 ]
#  [248.034799  ]
#  [169.2336892 ]
#  [129.6371619 ]
#  [160.5471107 ]
#  [ 62.67089721]
#  [ 51.44298395]
#  [350.2593982 ]
#  [ 87.25168606]
#  [311.743669  ]
#  [193.0901217 ]
#  [310.1584229 ]
#  [148.1785567 ]
#  [236.001644  ]
#  [328.6183478 ]
# ...

# %%
#Grafica del training data
plt.scatter(X_train_Simple, y_train_Simple, color = 'red')
plt.plot(X_train_Simple, regressor.predict(X_train_Simple), color = 'blue')
plt.title('Dummy Data')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
#Grafica del testing data
plt.scatter(X_test_Simple, y_test_Simple, color = 'red')
plt.plot(X_train_Simple, regressor.predict(X_train_Simple), color = 'blue')
plt.title('Dummy Data')
plt.xlabel('TV')
plt.ylabel('SALES')
plt.show()

# %%
#REGRESION LINEAL MULTIPLE
#========================
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
# Codificacion de datos categoricos
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[0.0 1.0 0.0 ... 16.0 6.566230788 2.907982773]
#  [0.0 1.0 0.0 ... 13.0 9.237764567 2.409567204]
#  [0.0 1.0 0.0 ... 41.0 15.88644602 2.913410175]
#  ...
#  [0.0 0.0 1.0 ... 44.0 19.80007236 5.096191875]
#  [1.0 0.0 0.0 ... 71.0 17.5346403 1.94087322]
#  [0.0 0.0 1.0 ... 42.0 15.96668752 5.046547629]]

# %%
#Segmentacion de los datos
from sklearn.model_selection import train_test_split
X_train_mult, X_test_mult, y_train_mult, y_test_mult = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Entrenamiento
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train_mult, y_train_mult)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test_mult)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test_mult.reshape(len(y_test_mult),1)),1))
# Out:
# [[277.74 277.24]
#  [234.89 236.16]
#  [167.26 167.72]
#  ...
#  [135.19 140.14]
#  [152.94 153.54]
#  [ 53.25  57.13]]

# %%
#Visualizacion de los resultados del conjunto de entrenamiento
import statsmodels.regression.linear_model as lm
X = np.append(arr = np.ones((4546, 1)).astype("int64"), values = X, axis = 1)
SL = 0.05

# %%
X_opt = X[:, [0, 1, 2, 3, 4, 5]].tolist()
"""X_opt = np.array(X_opt, dtype = "float64")"""
regression_OLS = lm.OLS(endog = y, exog = X_opt).fit()
regression_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.129e+06
# Date:                Sat, 17 Jun 2023   Prob (F-statistic):               0.00
# Time:                        21:35:47   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4541   BIC:                         2.277e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1056      0.081     -1.311      0.190      -0.263       0.052
# ...

# %%
X_opt = X[:, [0, 2, 3, 4, 5]].tolist()
"""X_opt = np.array(X_opt, dtype = "float64")"""
regression_OLS = lm.OLS(endog = y, exog = X_opt).fit()
regression_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.129e+06
# Date:                Sat, 17 Jun 2023   Prob (F-statistic):               0.00
# Time:                        21:59:18   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4541   BIC:                         2.277e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1018      0.128     -0.796      0.426      -0.352       0.149
# ...

# %%
X_opt = X[:, [0, 4, 5]].tolist()
"""X_opt = np.array(X_opt, dtype = "float64")"""
regression_OLS = lm.OLS(endog = y, exog = X_opt).fit()
regression_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.258e+06
# Date:                Sat, 17 Jun 2023   Prob (F-statistic):               0.00
# Time:                        22:00:00   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4543   BIC:                         2.276e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1177      0.104     -1.134      0.257      -0.321       0.086
# ...

# %%
X_opt = X[:, [0, 5]].tolist()
"""X_opt = np.array(X_opt, dtype = "float64")"""
regression_OLS = lm.OLS(endog = y, exog = X_opt).fit()
regression_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.517e+06
# Date:                Sat, 17 Jun 2023   Prob (F-statistic):               0.00
# Time:                        22:00:21   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4544   BIC:                         2.275e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1325      0.101     -1.317      0.188      -0.330       0.065
# ...

# %%
X = dataset.iloc[:, [0]].values
y = dataset.iloc[:, -1].values
